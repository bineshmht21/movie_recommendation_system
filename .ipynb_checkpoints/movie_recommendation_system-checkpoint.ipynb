# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rahulvyasm/netflix-movies-and-tv-shows")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\BineshMahato\.cache\kagglehub\datasets\rahulvyasm\netflix-movies-and-tv-shows\versions\1

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\BineshMahato\.cache\kagglehub\datasets\rahulvyasm\netflix-movies-and-tv-shows\versions\1\netflix_titles.csv",  encoding='ISO-8859-1')


# Display the first few rows
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing data (if necessary)
df = df.dropna()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# Unnamed: 12     8809
# Unnamed: 13     8809
# Unnamed: 14     8809
# Unnamed: 15     8809
# Unnamed: 16     8809
# Unnamed: 17     8809
# Unnamed: 18     8809
# Unnamed: 19     8809
# Unnamed: 20     8809
# Unnamed: 21     8809
# Unnamed: 22     8809
# Unnamed: 23     8809
# Unnamed: 24     8809
# Unnamed: 25     8809
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\BineshMahato\.cache\kagglehub\datasets\rahulvyasm\netflix-movies-and-tv-shows\versions\1\netflix_titles.csv",  encoding='ISO-8859-1')

# Define the function to combine selected features
def combine_features(row):
    return ' '.join([
        str(row['listed_in']) if pd.notna(row['listed_in']) else "",  # Assuming this contains genres
        str(row['description']) if pd.notna(row['description']) else "",  # Assuming you want to include description
        str(row['cast']) if pd.notna(row['cast']) else "",  # Handle missing cast data
        str(row['director']) if pd.notna(row['director']) else "",  # Handle missing director data
        str(row['rating']) if pd.notna(row['rating']) else ""  # Optionally, include rating
    ]).strip()

# Apply the function to each row and create the 'combined_features' column
df['combined_features'] = df.apply(lambda row: combine_features(row), axis=1)

# Display the first few rows of the updated dataframe
print(df[['title', 'combined_features']].head())
# Out:
#                    title                                  combined_features
# 0   Dick Johnson Is Dead  Documentaries As her father nears the end of h...
# 1          Blood & Water  International TV Shows, TV Dramas, TV Mysterie...
# 2              Ganglands  Crime TV Shows, International TV Shows, TV Act...
# 3  Jailbirds New Orleans  Docuseries, Reality TV Feuds, flirtations and ...
# 4           Kota Factory  International TV Shows, Romantic TV Shows, TV ...

# %%
# Convert text data to numerical using CountVectorizer
vectorizer = CountVectorizer()
feature_matrix = vectorizer.fit_transform(df['combined_features'])

# %%
# Calculate similarity scores
cosine_sim = cosine_similarity(feature_matrix)

# %%
# Create a function to recommend movies based on cosine similarity
def recommend_movie(movie_title, num_recommendations=5):
    # Find the index of the movie in the dataset
    movie_index = df[df['title'] == movie_title].index[0]
    
    # Get the similarity scores for the given movie
    similar_movies = list(enumerate(cosine_sim[movie_index]))
    
    # Sort movies by similarity score
    sorted_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)
    
    # Get the titles of the top 'num_recommendations' movies
    recommended_movies = [df['title'][i[0]] for i in sorted_movies[1:num_recommendations+1]]
    
    return recommended_movies

# %%
# Test the function
print(recommend_movie("The Matrix"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # Test the function
# ----> 2 print(recommend_movie("The Matrix"))
#
# Cell In[51], line 4, in recommend_movie(movie_title, num_recommendations)
#       2 def recommend_movie(movie_title, num_recommendations=5):
#       3     # Find the index of the movie in the dataset
# ----> 4     movie_index = df[df['title'] == movie_title].index[1]
#       6     # Get the similarity scores for the given movie
#       7     similar_movies = list(enumerate(cosine_sim[movie_index]))
#
# File ~\anaconda3\envs\tf_env\lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
# ...
